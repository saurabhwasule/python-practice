# %% [markdown]
# # Working with Text Data

# %%
import pandas as pd
chicago=pd.read_csv("practice_csv\chicago.csv").dropna(how="all")
chicago["Department"]=chicago["Department"].astype("category")
chicago["Position Title"]=chicago["Position Title"].astype("category")
chicago
# Out:
#                            Name  \
# 0               AARON,  ELVIA J
# 1             AARON,  JEFFERY M
# 2                AARON,  KARINA
# 3           AARON,  KIMBERLEI R
# 4           ABAD JR,  VICENTE M
# 5               ABARCA,  ANABEL
# 6             ABARCA,  EMMANUEL
# 7             ABASCAL,  REECE E
# 8          ABBASI,  CHRISTOPHER
# 9         ABBATACOLA,  ROBERT J
# 10        ABBATEMARCO,  JAMES J
# 11             ABBATE,  TERRY M
# 12             ABBOTT,  BETTY L
# 13            ABBOTT,  LYNISE M
# 14       ABBRUZZESE,  WILLIAM J
# 15              ABDALLAH,  ZAID
# 16        ABDELHADI,  ABDALMAHD
# 17          ABDELLATIF,  AREF R
# 18           ABDELMAJEID,  AZIZ
# 19          ABDOLLAHZADEH,  ALI
# 20     ABDUL-KARIM,  MUHAMMAD A
# 21          ABDULLAH,  DANIEL N
# 22             ABDULLAH,  KEVIN
# 23         ABDULLAH,  LAKENYA N
# 24          ABDULLAH,  RASHAD J
# 25         ABDULSATTAR,  MUDHAR
# 26         ABDUL-SHAKUR,  TAHIR
# 27       ABDULWAHAB,  ABUUBAIDA
# ...

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null category
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(2), object(2)
# memory usage: 895.4+ KB

# %%
chicago["Name"].str.lower().head(3) # to convert column to lower case
# Out:
# 0      aaron,  elvia j
# 1    aaron,  jeffery m
# 2       aaron,  karina
# Name: Name, dtype: object

# %%
chicago["Name"].str.lower().str.upper().head(3)
# Out:
# 0      AARON,  ELVIA J
# 1    AARON,  JEFFERY M
# 2       AARON,  KARINA
# Name: Name, dtype: object

# %%
chicago["Name"].str.lower().str.title().head(3)# to convert column to title case (first letter of each word as capital)
# Out:
# 0      Aaron,  Elvia J
# 1    Aaron,  Jeffery M
# 2       Aaron,  Karina
# Name: Name, dtype: object

# %%
chicago["Name"].str.len().head(3)# to get length of each string
# Out:
# 0    15
# 1    17
# 2    14
# Name: Name, dtype: int64

# %%
chicago["Department"]=chicago["Department"].str.replace("MGMNT","MANAGEMENT").astype("category")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
chicago["Employee Annual Salary"]=chicago["Employee Annual Salary"].str.replace("$","").astype("float")
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER  WATER MANAGEMENT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV  WATER MANAGEMENT
#
#    Employee Annual Salary
# 0                 90744.0
# 1                 84450.0
# 2                 84450.0
# 3                 89880.0
# 4                106836.0

# %%
chicago["Employee Annual Salary"].sum()
chicago["Employee Annual Salary"].mean()
chicago["Employee Annual Salary"].std()
chicago["Employee Annual Salary"].nlargest(3)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# Name: Employee Annual Salary, dtype: float64

# %%
chicago["Name"].str.strip().head(3) #remove leding and trailing whitespace
# Out:
# 0      AARON,  ELVIA J
# 1    AARON,  JEFFERY M
# 2       AARON,  KARINA
# Name: Name, dtype: object

# %%
#chanaging dataframe index to Name column
chicago.set_index("Name",inplace=True)
chicago.head(3)
# Out:
#                      Position Title        Department  Employee Annual Salary
# Name
# AARON,  ELVIA J    WATER RATE TAKER  WATER MANAGEMENT                 90744.0
# AARON,  JEFFERY M    POLICE OFFICER            POLICE                 84450.0
# AARON,  KARINA       POLICE OFFICER            POLICE                 84450.0

# %% [markdown]
# # 4.Filtering with String Methods

# %%
cond=chicago["Position Title"].str.lower().str.contains("water")#looks for "water" anywhere in the string
chicago[cond].head(3)
# Out:
#                    Name                      Position Title        Department  \
# 0       AARON,  ELVIA J                    WATER RATE TAKER  WATER MANAGEMENT
# 554  ALUISE,  VINCENT G  FOREMAN OF WATER PIPE CONSTRUCTION  WATER MANAGEMENT
# 671     ANDER,  PERRY A                    WATER CHEMIST II  WATER MANAGEMENT
#
#      Employee Annual Salary
# 0                   90744.0
# 554                102440.0
# 671                 82044.0

# %%
cond=chicago["Position Title"].str.lower().str.startswith("water")#looks for "water" only at the beginning 
chicago[cond].head(3)
# Out:
#                   Name    Position Title        Department  \
# 0      AARON,  ELVIA J  WATER RATE TAKER  WATER MANAGEMENT
# 671    ANDER,  PERRY A  WATER CHEMIST II  WATER MANAGEMENT
# 1054  ASHLEY,  KARMA T  WATER CHEMIST II  WATER MANAGEMENT
#
#       Employee Annual Salary
# 0                    90744.0
# 671                  82044.0
# 1054                 82044.0

# %%
cond=chicago["Position Title"].str.lower().str.endswith("ist")#looks for only only at the end of the string 
chicago[cond].head(3)
# Out:
#                  Name                        Position Title  \
# 184    AFROZ,  NAYYAR                          PSYCHIATRIST
# 308  ALARCON,  LUIS J            LOAN PROCESSING SPECIALIST
# 422  ALLAIN,  CAROLYN  SENIOR TELECOMMUNICATIONS SPECIALIST
#
#                 Department  Employee Annual Salary
# 184                 HEALTH                 99840.0
# 308  COMMUNITY DEVELOPMENT                 81948.0
# 422                   DoIT                 89880.0
